# %%
import pandas as pd

# %%
# !pip install pandas

# %%
pd.Series([1,2,4,3,5,8])
# Out:
# 0    1
# 1    2
# 2    4
# 3    3
# 4    5
# 5    8
# dtype: int64

# %%
df=pd.DataFrame({"name":["h
arry","rohgan","karthik"],"marks":[12,45,89]})

# %%
df
# Out:
#       name  marks
# 0    harry     12
# 1   rohgan     45
# 2  karthik     89

# %% [markdown]
# Series are 1D
# Df are for tables format
