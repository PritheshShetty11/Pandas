# %%
import pandas as pd

# %%
df=pd.read_csv("data2.csv")

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.sort_values("Year")
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.sort_values(["Year","IMDb"])
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2=df.sort_values(["Year","IMDb"],ascending=False).copy()

# %%
df2.sort_index()
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2.reset_index()
# Out:
#     index               Actor                      Film  Year  \
# 0       0      Shah Rukh Khan                   Pathaan  2023
# 1       9       Kartik Aaryan         Bhool Bhulaiyaa 2  2022
# 2       3       Ranbir Kapoor                Brahmastra  2022
# 3      11       Vicky Kaushal  Uri: The Surgical Strike  2019
# 4       8        Akshay Kumar                Good Newwz  2019
# 5       7      Hrithik Roshan                       War  2019
# 6       5  Ayushmann Khurrana                 Andhadhun  2018
# 7       6       Rajkummar Rao                     Stree  2018
# 8       4       Ranveer Singh                 Padmaavat  2018
# 9      10        Varun Dhawan     Badrinath Ki Dulhania  2017
# 10      1         Salman Khan           Tiger Zinda Hai  2017
# 11      2          Aamir Khan                    Dangal  2016
#
#               Genre  BoxOffice(INR Crore)  IMDb
# 0            Action                  1050   7.2
# 1     Horror Comedy                   266   5.9
# ...

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2.reset_index(drop=True)
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 2        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 3        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 4         Akshay Kumar                Good Newwz  2019           Comedy
# 5       Hrithik Roshan                       War  2019           Action
# 6   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7        Rajkummar Rao                     Stree  2018    Horror Comedy
# 8        Ranveer Singh                 Padmaavat  2018       Historical
# 9         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 10         Salman Khan           Tiger Zinda Hai  2017           Action
# 11          Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2.reset_index(drop=True,inplace=True)

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 2        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 3        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 4         Akshay Kumar                Good Newwz  2019           Comedy
# 5       Hrithik Roshan                       War  2019           Action
# 6   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7        Rajkummar Rao                     Stree  2018    Horror Comedy
# 8        Ranveer Singh                 Padmaavat  2018       Historical
# 9         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 10         Salman Khan           Tiger Zinda Hai  2017           Action
# 11          Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2["Rank"]=df2["IMDb"].rank(method="dense",ascending=True).copy()

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 2        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 3        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 4         Akshay Kumar                Good Newwz  2019           Comedy
# 5       Hrithik Roshan                       War  2019           Action
# 6   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7        Rajkummar Rao                     Stree  2018    Horror Comedy
# 8        Ranveer Singh                 Padmaavat  2018       Historical
# 9         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 10         Salman Khan           Tiger Zinda Hai  2017           Action
# 11          Aamir Khan                    Dangal  2016        Biography
#
# ...

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 2        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 3        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 4         Akshay Kumar                Good Newwz  2019           Comedy
# 5       Hrithik Roshan                       War  2019           Action
# 6   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7        Rajkummar Rao                     Stree  2018    Horror Comedy
# 8        Ranveer Singh                 Padmaavat  2018       Historical
# 9         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 10         Salman Khan           Tiger Zinda Hai  2017           Action
# 11          Aamir Khan                    Dangal  2016        Biography
#
# ...

# %%
df2["Rank"]=df["IMDb"].rank(ascending=False,method="dense").copy()

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 2        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 3        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 4         Akshay Kumar                Good Newwz  2019           Comedy
# 5       Hrithik Roshan                       War  2019           Action
# 6   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7        Rajkummar Rao                     Stree  2018    Horror Comedy
# 8        Ranveer Singh                 Padmaavat  2018       Historical
# 9         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 10         Salman Khan           Tiger Zinda Hai  2017           Action
# 11          Aamir Khan                    Dangal  2016        Biography
#
# ...

# %%
df2.sort_values("Rank")
# Out:
#                  Actor                      Film  Year            Genre  \
# 2        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 5       Hrithik Roshan                       War  2019           Action
# 11          Aamir Khan                    Dangal  2016        Biography
# 6   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 4         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Ranveer Singh                 Padmaavat  2018       Historical
# 7        Rajkummar Rao                     Stree  2018    Horror Comedy
# 10         Salman Khan           Tiger Zinda Hai  2017           Action
# 1        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 9         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
# ...

# %%
df2.rename(columns={"Genre":"Type"},inplace=True)

# %%
df2
# Out:
#                  Actor                      Film  Year             Type  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 2        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 3        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 4         Akshay Kumar                Good Newwz  2019           Comedy
# 5       Hrithik Roshan                       War  2019           Action
# 6   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7        Rajkummar Rao                     Stree  2018    Horror Comedy
# 8        Ranveer Singh                 Padmaavat  2018       Historical
# 9         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 10         Salman Khan           Tiger Zinda Hai  2017           Action
# 11          Aamir Khan                    Dangal  2016        Biography
#
# ...

# %%
cols=["Type"]+[col for col in df2.columns if col!="Type"]

# %%
cols
# Out:
# ['Type', 'Actor', 'Film', 'Year', 'BoxOffice(INR Crore)', 'IMDb', 'Rank']

# %%
df2.columns
# Out:
# Index(['Actor', 'Film', 'Year', 'Type', 'BoxOffice(INR Crore)', 'IMDb',
#        'Rank'],
#       dtype='str')

# %%
df2.co
