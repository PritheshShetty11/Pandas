# %%
import pandas as pd
 
data = [
    ["Alice", 25],
    ["Bob", 30],
    ["Charlie", 35]
]

# %%
data
# Out:
# [['Alice', 25], ['Bob', 30], ['Charlie', 35]]

# %%
pd.DataFrame(data,columns=["name","col"])
# Out:
#       name  col
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35]
}

# %%
data
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35]}

# %%
pd.DataFrame(data)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
import numpy as np

# %%
arr=np.array([[1,2,3],[5,4,3]])

# %%
arr
# Out:
# array([[1, 2, 3],
#        [5, 4, 3]])

# %%
df=pd.DataFrame(arr,columns=["A","B","C"])

# %%
df
# Out:
#    A  B  C
# 0  1  2  3
# 1  5  4  3

# %%
df=pd.read_excel("data.xlsx")

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\dell\anaconda3\envs\prithenv\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\dell\anaconda3\envs\prithenv\lib\site-packages (from openpyxl) (2.0.0)

# %%
df
# Out:
#   name  marks
# 0    a     12
# 1    s      3
# 2    d     45
# 3    f      6
# 4   hj     42

# %%
df=pd.read_csv("data.csv")

# %%
df
# Out:
#   name  marks
# 0    a     12
# 1    s      3
# 2    d     45
# 3    f      6
# 4   hj     42

# %%
df=pd.read_json("data.json")

# %%
df
# Out:
#              name  age
# 0        Prithesh   22
# 1  Pritheshshetty   29
