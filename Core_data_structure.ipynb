# %%
import pandas as pd
s=pd.Series([11,22,34,54,32,45,65])

# %%
type(s)
# Out:
# pandas.Series

# %%
print(s)
# Out:
# 0    11
# 1    22
# 2    34
# 3    54
# 4    32
# 5    45
# 6    65
# dtype: int64

# %%
s1=pd.Series([11,22,34,54,32,45,65],index=["a","a","b","a","a","a","a"])

# %%
s1
# Out:
# a    11
# a    22
# b    34
# a    54
# a    32
# a    45
# a    65
# dtype: int64

# %%
s1["b"]
# Out:
# np.int64(34)

# %%
data = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Bangalore"]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='str')
